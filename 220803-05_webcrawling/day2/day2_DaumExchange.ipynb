# %% [markdown]
# ### daum exchange
# - 환율정보 수집
# - headers : referer, user-agent

# %%
import requests
import pandas as pd

# %%
# 실습 과제
# https://finance.daum.net/exchanges
# headers : referer, user-agent 설정
headers = {"referer" : 'https://finance.daum.net/exchanges/FRX.KRWUSD', "user-agent" : 'Mozilla/5.0'}
url = 'https://finance.daum.net/api/exchanges/FRX.KRWUSD/days?symbolCode=FRX.KRWUSD&terms=days&page=1&perPage=10'
response = requests.get(url, headers=headers)
data = response.json()["data"]
df = pd.DataFrame(data)
df
# Out:
#    symbolCode                 date currencyCode currencyName  currencyUnit  \
# 0  FRX.KRWUSD  2022-08-04 13:48:43          USD           달러             1
# 1  FRX.KRWUSD  2022-08-03 23:56:54          USD           달러             1
# 2  FRX.KRWUSD  2022-08-02 23:43:30          USD           달러             1
# 3  FRX.KRWUSD  2022-08-01 23:46:59          USD           달러             1
# 4  FRX.KRWUSD  2022-07-31 16:17:45          USD           달러             1
# 5  FRX.KRWUSD  2022-07-29 23:57:09          USD           달러             1
# 6  FRX.KRWUSD  2022-07-28 23:42:51          USD           달러             1
# 7  FRX.KRWUSD  2022-07-27 23:48:14          USD           달러             1
# 8  FRX.KRWUSD  2022-07-26 22:31:59          USD           달러             1
# 9  FRX.KRWUSD  2022-07-25 23:36:56          USD           달러             1
#
#   country                                     region          name  \
# 0      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 1      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 2      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 3      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 4      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 5      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 6      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 7      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 8      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
# 9      미국  {'korName': '아메리카', 'engName': 'America'}  미국 (KRW/USD)
#
#    recurrenceCount  basePrice  ... changeRate  cashBuyingPrice  \
# 0              211     1310.7  ...   0.000991          1333.63
# 1              428     1312.0  ...   0.000000          1334.96
# 2              403     1312.0  ...   0.005364          1334.96
# 3              372     1305.0  ...   0.000383          1327.83
# 4              404     1304.5  ...   0.001913          1327.32
# 5              402     1307.0  ...   0.002685          1329.87
# 6              511     1303.5  ...   0.007991          1326.31
# 7              412     1314.0  ...   0.002288          1336.99
# 8              429     1311.0  ...   0.000762          1333.94
# 9              525     1312.0  ...   0.001527          1334.96
#
#    cashSellingPrice  ttBuyingPrice  ttSellingPrice  tcBuyingPrice  \
# 0           1287.77         1297.9          1323.5           None
# 1           1289.04         1299.2          1324.8           None
# 2           1289.04         1299.2          1324.8           None
# 3           1282.17         1292.3          1317.7           None
# 4           1281.68         1291.8          1317.2           None
# 5           1284.13         1294.2          1319.8           None
# 6           1280.69         1290.8          1316.2           None
# 7           1291.01         1301.2          1326.8           None
# 8           1288.06         1298.2          1323.8           None
# 9           1289.04         1299.2          1324.8           None
#
#    fcSellingPrice exchangeCommission usDollarRate  \
# 0            None             4.1374          1.0
# 1            None             4.1352          1.0
# 2            None             4.1354          1.0
# 3            None             4.1347          1.0
# 4            None             4.1574          1.0
# 5            None             4.1574          1.0
# 6            None             4.1770          1.0
# 7            None             4.1718          1.0
# 8            None             4.1361          1.0
# 9            None             4.1346          1.0
#
#                                        chartImageUrl
# 0  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 1  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 2  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 3  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 4  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 5  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 6  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 7  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 8  {'day': 'https://t1.daumcdn.net/finance/chart/...
# 9  {'day': 'https://t1.daumcdn.net/finance/chart/...
#
# [10 rows x 22 columns]

# %%
# 1. 웹서비스 분석 : URL

# %%
url = 'https://finance.daum.net/api/exchanges/summaries'

# %%
# 2. request > response : JSON(str)

# %%
header = {
    "user-agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    "referer" : 'https://finance.daum.net/exchanges',
}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
# 3. JSON(str) > DataFrame

# %%
data = response.json()["data"]
df = pd.DataFrame(data)[['symbolCode','currencyCode','basePrice']]
df
# Out:
#     symbolCode currencyCode  basePrice
# 0   FRX.KRWUSD          USD    1310.90
# 1   FRX.KRWJPY          JPY     980.52
# 2   FRX.KRWCNY          CNY     193.90
# 3   FRX.KRWEUR          EUR    1332.79
# 4   FRX.KRWGBP          GBP    1593.92
# 5   FRX.KRWCHF          CHF    1364.24
# 6   FRX.KRWCAD          CAD    1020.71
# 7   FRX.KRWNZD          NZD     825.08
# 8   FRX.KRWHKD          HKD     167.01
# 9   FRX.KRWBRL          BRL     248.09
# 10  FRX.KRWMXN          MXN      64.07
# 11  FRX.KRWAED          AED     356.89
# 12  FRX.KRWKWD          KWD    4273.37
# 13  FRX.KRWBHD          BHD    3477.19
# 14  FRX.KRWINR          INR      16.51
# 15  FRX.KRWSAR          SAR     348.64
# 16  FRX.KRWNOK          NOK     135.05
# 17  FRX.KRWDKK          DKK     179.08
# 18  FRX.KRWMYR          MYR     294.30
# 19  FRX.KRWBDT          BDT      13.84
# 20  FRX.KRWPKR          PKR       5.89
# 21  FRX.KRWIDR          IDR       8.80
# 22  FRX.KRWTWD          TWD      43.66
# 23  FRX.KRWPHP          PHP      23.52
# 24  FRX.KRWSEK          SEK     128.39
# 25  FRX.KRWAUD          AUD     912.52
# 26  FRX.KRWSGD          SGD     949.89
# 27  FRX.KRWTHB          THB      36.23
# 28  FRX.KRWEGP          EGP      68.71
# 29  FRX.KRWBND          BND     949.89
# 30  FRX.KRWILS          ILS     390.46
# 31  FRX.KRWJOD          JOD    1848.94
# 32  FRX.KRWVND          VND       5.60
# 33  FRX.KRWRUB          RUB      21.69
# 34  FRX.KRWHUF          HUF       3.38
# 35  FRX.KRWPLN          PLN     283.67
# 36  FRX.KRWZAR          ZAR      78.22
# 37  FRX.KRWMNT          MNT       0.41
# 38  FRX.KRWCZK          CZK      54.08
# 39  FRX.KRWKZT          KZT       2.75
# 40  FRX.KRWQAR          QAR     357.88
# 41  FRX.KRWTRY          TRY      73.06
