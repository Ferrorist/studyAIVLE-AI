# %% [markdown]
# # 안녕하세요^^
# # AIVLE 2차 미니 프로젝트에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
#
# * "1. 데이터 불러오기 및 분석" 단계에서는 제공되는 데이터를 불러와 feature들을 확인 해보는 작업을 진행 합니다.

# %% [markdown]
# ---

# %%
# 필요 라이브러리부터 설치할께요.
# %pip install pandas seaborn

# %% [markdown]
# ---

# %% [markdown]
# ## 기본 데이터
#
# * 21년도 데이터 train 데이터
# * 22년도 데이터 test 데이터
#
# [미세먼지 데이터]
# * 21년도 미세먼지 데이터 : air_2021.csv
# * 22년도 미세먼지 데이터 : air_2022.csv
#
# [날씨 데이터]
# * 21년도 날씨 데이터 : weather_2021.csv
# * 22년도 날씨 데이터 : weather_2022.csv

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 불러오기
# ## 서울시 미세먼지 데이터와 기상 데이터를 불러오도록 하겠습니다.

# %% [markdown]
# #### [실습문제1] 미세먼지 데이터 로딩
# * Pandas 라이브러리를 활용해서 'air_2021.csv'파일을 'air_21' 변수에, 'air_2022.csv'파일을 'air_22' 변수에 저장하고 그 데이터를 확인하세요.
# * 아래에 'Pandas'를 Import하고 두 개의 파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * encoder = 'UTF-8'
# * index_col = 0

# %%
#기본 라이브러리들
import numpy as np   # 수치연산
import pandas as pd  # 데이터프레임(2차원) 
import matplotlib.pyplot as plt  # 그래프
import seaborn as sns

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

from datetime import datetime, timedelta

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 100)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
air_21 = pd.read_csv('air_2021.csv', sep=',',encoding='UTF-8', index_col=0)
air_22 = pd.read_csv('air_2022.csv', sep=',',encoding='UTF-8', index_col=0)

# %%
# 데이터 프레임의 Shape을 확인합니다.
air_21.shape, air_22.shape
# Out:
# ((8760, 12), (2160, 12))

# %% [markdown]
# #### [실습문제2] 날씨 데이터 로딩
# * Pandas 라이브러리를 활용해서 'weather_2021.csv'파일을 'weather_21' 변수에, 'weather_2022.csv'파일을 'weather_22' 변수에 저장하고 그 데이터를 확인하세요.
# * 아래에 'Pandas'를 Import하고 두 개의 파일을 불러오고 Shape을 확인하는 소스코드를 작성하고 실행해보세요.
# * 구분자(sep) : ','
# * encoder = 'cp949'

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
weather_21 = pd.read_csv('weather_2021.csv', sep=',', encoding='cp949', index_col=0)
weather_22 = pd.read_csv('weather_2022.csv', sep=',', encoding='cp949', index_col=0)

# %%
# 데이터 프레임의 Shape을 확인합니다.
weather_21.shape, weather_22.shape
# Out:
# ((8759, 37), (2160, 37))

# %% [markdown]
# ---

# %% [markdown]
# # 2. 다양한 변수 확인

# %% [markdown]
# #### [실습문제3] 미세먼지 데이터와 날씨 데이터의 다양한 변수를 확인해 보도록 하겠습니다
#
# * 미세먼지 데이터 : https://www.airkorea.or.kr/web/last_amb_hour_data?pMENU_NO=123
#
#
# * 날씨 데이터 : https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36
#
# * 도메인 지식 습득과 함께 변수에 대한 정보를 직접 파악해 보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
air_21.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2021100101  0.003  0.6  0.002  0.039  31.0
# 1  서울 종로구  도시대기  111123  종로구  2021100102  0.003  0.6  0.002  0.035  27.0
# 2  서울 종로구  도시대기  111123  종로구  2021100103  0.003  0.6  0.002  0.033  28.0
# 3  서울 종로구  도시대기  111123  종로구  2021100104  0.003  0.6  0.002  0.030  26.0
# 4  서울 종로구  도시대기  111123  종로구  2021100105  0.003  0.5  0.003  0.026  26.0
#
#    PM25                주소
# 0  18.0  서울 종로구 종로35가길 19
# 1  16.0  서울 종로구 종로35가길 19
# 2  18.0  서울 종로구 종로35가길 19
# 3  16.0  서울 종로구 종로35가길 19
# 4  16.0  서울 종로구 종로35가길 19

# %%
air_22.head()
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0  서울 종로구  도시대기  111123  종로구  2022010101  0.003  0.4  0.026  0.016  23.0
# 1  서울 종로구  도시대기  111123  종로구  2022010102  0.003  0.4  0.022  0.020  20.0
# 2  서울 종로구  도시대기  111123  종로구  2022010103  0.003  0.5  0.014  0.028  20.0
# 3  서울 종로구  도시대기  111123  종로구  2022010104  0.003  0.5  0.016  0.027  19.0
# 4  서울 종로구  도시대기  111123  종로구  2022010105  0.003  0.5  0.005  0.040  24.0
#
#    PM25                주소
# 0  12.0  서울 종로구 종로35가길 19
# 1   9.0  서울 종로구 종로35가길 19
# 2   9.0  서울 종로구 종로35가길 19
# 3  10.0  서울 종로구 종로35가길 19
# 4  11.0  서울 종로구 종로35가길 19

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
weather_21.head()
# Out:
#     지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 지점
# 108  서울  2021-01-01 01:00    -8.7       NaN      NaN        NaN      2.4
# 108  서울  2021-01-01 02:00    -9.1       NaN      NaN        NaN      1.6
# 108  서울  2021-01-01 03:00    -9.3       NaN      NaN        NaN      1.1
# 108  서울  2021-01-01 04:00    -9.3       NaN      NaN        NaN      0.3
# 108  서울  2021-01-01 05:00    -9.7       NaN      NaN        NaN      1.9
#
#      풍속 QC플래그  풍향(16방위)  풍향 QC플래그  습도(%)  습도 QC플래그  증기압(hPa)  이슬점온도(°C)  \
# 지점
# 108       NaN     270.0       NaN     68       NaN       2.2      -13.5
# 108       NaN     270.0       NaN     69       NaN       2.1      -13.7
# 108       NaN     250.0       NaN     70       NaN       2.1      -13.7
# 108       NaN       0.0       NaN     71       NaN       2.2      -13.5
# 108       NaN      20.0       NaN     72       NaN       2.1      -13.8
#
#      현지기압(hPa)  현지기압 QC플래그  해면기압(hPa)  해면기압 QC플래그  일조(hr)  일조 QC플래그  \
# 지점
# 108     1016.4         NaN     1027.7         NaN     NaN       9.0
# 108     1016.2         NaN     1027.5         NaN     NaN       9.0
# 108     1016.8         NaN     1028.1         NaN     NaN       9.0
# 108     1016.2         NaN     1027.5         NaN     NaN       9.0
# 108     1015.6         NaN     1026.9         NaN     NaN       9.0
#
#      일사(MJ/m2)  일사 QC플래그  적설(cm)  3시간신적설(cm)  전운량(10분위)  중하층운량(10분위) 운형(운형약어)  \
# 지점
# 108        NaN       9.0     NaN         NaN        0.0            0      NaN
# 108        NaN       9.0     NaN         NaN        0.0            0      NaN
# 108        NaN       9.0     NaN         NaN        0.0            0      NaN
# 108        NaN       9.0     NaN         NaN        0.0            0      NaN
# 108        NaN       9.0     NaN         NaN        0.0            0      NaN
#
#      최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C)  지면온도 QC플래그  \
# 지점
# 108          NaN     2000           NaN        NaN      -6.9         NaN
# 108          NaN     2000           NaN        NaN      -7.1         NaN
# 108          NaN     2000           NaN        NaN      -7.3         NaN
# 108          NaN     2000           NaN        NaN      -7.5         NaN
# 108          NaN     2000           NaN        NaN      -7.6         NaN
#
#      5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 지점
# 108          -1.0           -0.8            0.3            1.6
# 108          -1.1           -0.8            0.3            1.6
# 108          -1.2           -0.9            0.3            1.6
# 108          -1.3           -1.0            0.2            1.5
# 108          -1.3           -1.0            0.2            1.5

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
weather_22.head()
# Out:
#     지점명                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 지점
# 108  서울  2022-01-01 00:00    -8.5       NaN      NaN        NaN      1.9
# 108  서울  2022-01-01 01:00    -9.2       NaN      NaN        NaN      1.8
# 108  서울  2022-01-01 02:00    -9.5       NaN      NaN        NaN      1.2
# 108  서울  2022-01-01 03:00    -9.3       NaN      NaN        NaN      1.4
# 108  서울  2022-01-01 04:00    -9.6       NaN      NaN        NaN      1.7
#
#      풍속 QC플래그  풍향(16방위)  풍향 QC플래그  습도(%)  습도 QC플래그  증기압(hPa)  이슬점온도(°C)  \
# 지점
# 108       NaN       320       NaN     41       NaN       1.3      -19.4
# 108       NaN       270       NaN     42       NaN       1.3      -19.7
# 108       NaN       270       NaN     43       NaN       1.3      -19.7
# 108       NaN       290       NaN     46       NaN       1.4      -18.8
# 108       NaN       340       NaN     48       NaN       1.4      -18.5
#
#      현지기압(hPa)  현지기압 QC플래그  해면기압(hPa)  해면기압 QC플래그  일조(hr)  일조 QC플래그  \
# 지점
# 108     1021.9         NaN     1033.2         NaN     NaN       9.0
# 108     1022.2         NaN     1033.6         NaN     NaN       9.0
# 108     1022.3         NaN     1033.7         NaN     NaN       9.0
# 108     1022.6         NaN     1034.0         NaN     NaN       9.0
# 108     1021.9         NaN     1033.3         NaN     NaN       9.0
#
#      일사(MJ/m2)  일사 QC플래그  적설(cm)  3시간신적설(cm)  전운량(10분위)  중하층운량(10분위) 운형(운형약어)  \
# 지점
# 108        NaN       9.0     NaN         NaN          0            0      NaN
# 108        NaN       9.0     NaN         NaN          0            0      NaN
# 108        NaN       9.0     NaN         NaN          0            0      NaN
# 108        NaN       9.0     NaN         NaN          0            0      NaN
# 108        NaN       9.0     NaN         NaN          0            0      NaN
#
#      최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  지면온도(°C)  지면온도 QC플래그  \
# 지점
# 108          NaN     2000           NaN        NaN      -7.0         NaN
# 108          NaN     2000           NaN        NaN      -7.2         NaN
# 108          NaN     2000           NaN        NaN      -7.5         NaN
# 108          NaN     2000           NaN        NaN      -7.6         NaN
# 108          NaN     2000           NaN        NaN      -7.6         NaN
#
#      5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  30cm 지중온도(°C)
# 지점
# 108          -1.0           -1.0           -0.2            1.0
# 108          -1.1           -1.1           -0.2            1.0
# 108          -1.3           -1.2           -0.2            1.0
# 108          -1.4           -1.2           -0.2            1.0
# 108          -1.4           -1.3           -0.3            1.0

# %% [markdown]
# ---

# %%
weather_21.isna().sum()
# Out:
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         8759
# 강수량(mm)          7810
# 강수량 QC플래그        6996
# 풍속(m/s)             2
# 풍속 QC플래그         8757
# 풍향(16방위)            2
# 풍향 QC플래그         8757
# 습도(%)               0
# 습도 QC플래그         8759
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       8759
# 해면기압(hPa)           0
# 해면기압 QC플래그       8759
# 일조(hr)           3968
# 일조 QC플래그         4791
# 일사(MJ/m2)        3968
# 일사 QC플래그         4791
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 운형(운형약어)         3812
# 최저운고(100m )      4212
# 시정(10m)             0
# 지면상태(지면상태코드)     8759
# 현상번호(국내식)        6634
# 지면온도(°C)            5
# 지면온도 QC플래그       8735
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# dtype: int64

# %% [markdown]
# # 3. 데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 관측치들의 패턴 탐색
#   * 잘못된 자료들을 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제4] 미세먼지 데이터 알아보기
# * air_21,air_22 의 다양한 변수에 대하여 여러 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
air_21.columns
# Out:
# Index(['지역', '망', '측정소코드', '측정소명', '측정일시', 'SO2', 'CO', 'O3', 'NO2', 'PM10',
#        'PM25', '주소'],
#       dtype='object')

# %%
weather_21.columns
# Out:
# Index(['지점명', '일시', '기온(°C)', '기온 QC플래그', '강수량(mm)', '강수량 QC플래그', '풍속(m/s)',
#        '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그', '습도(%)', '습도 QC플래그', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그', '해면기압(hPa)', '해면기압 QC플래그',
#        '일조(hr)', '일조 QC플래그', '일사(MJ/m2)', '일사 QC플래그', '적설(cm)', '3시간신적설(cm)',
#        '전운량(10분위)', '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)',
#        '지면상태(지면상태코드)', '현상번호(국내식)', '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)',
#        '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
cols = ['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']
good = [0.02, 2, 0.03, 0.03, 30]
normal = [0.05, 9, 0.09, 0.06, 80]
bad = [0.15,  15, 0.15, 0.2, 150] # 에어코리아 - 통합대기환경지수 기준
# PM10 - 논문 '시계열 분석을 활용한 서울시 미세먼지' 예측 2페이지
plt.figure(figsize=(10,8))
for i in range(len(cols)):
    sns.kdeplot(air_21[cols[i]])
    if(i < len(good)):
        plt.axvline(x=good[i], color = 'skyblue')
        plt.axvline(x=normal[i], color = 'green')
        plt.axvline(x=bad[i], color = 'purple')
    plt.show()

# %%
air_21.describe()
# Out:
#           측정소코드          SO2           CO           O3          NO2  \
# count    8760.0  8648.000000  8680.000000  8663.000000  8680.000000
# mean   111123.0     0.003385     0.505645     0.029246     0.023346
# std         0.0     0.000826     0.209516     0.019708     0.014456
# min    111123.0     0.001000     0.200000     0.000000     0.003000
# 25%    111123.0     0.003000     0.400000     0.015000     0.012000
# 50%    111123.0     0.003000     0.400000     0.028000     0.019000
# 75%    111123.0     0.004000     0.600000     0.040000     0.031000
# max    111123.0     0.011000     2.000000     0.137000     0.082000
#
#               PM10         PM25         hour
# count  8655.000000  8663.000000  8760.000000
# mean     38.925361    20.466005    11.500000
# std      47.470577    16.564915     6.922582
# min       3.000000     1.000000     0.000000
# 25%      18.000000    10.000000     5.750000
# 50%      30.000000    16.000000    11.500000
# 75%      46.000000    25.000000    17.250000
# max     942.000000   154.000000    23.000000

# %%
air_21.loc[air_21['O3'] > good[2]].describe()
# Out:
#           측정소코드          SO2           CO           O3          NO2  \
# count    3742.0  3722.000000  3742.000000  3742.000000  3742.000000
# mean   111123.0     0.003454     0.419882     0.046710     0.015623
# std         0.0     0.000884     0.112540     0.015561     0.007466
# min    111123.0     0.001000     0.200000     0.031000     0.004000
# 25%    111123.0     0.003000     0.300000     0.035000     0.010000
# 50%    111123.0     0.003000     0.400000     0.042000     0.014000
# 75%    111123.0     0.004000     0.500000     0.053000     0.019000
# max    111123.0     0.011000     1.100000     0.137000     0.055000
#
#               PM10         PM25         hour
# count  3730.000000  3732.000000  3742.000000
# mean     37.838606    18.825831    13.366649
# std      39.595775    14.091069     6.383682
# min       3.000000     1.000000     0.000000
# 25%      18.000000    10.000000    10.000000
# 50%      29.000000    16.000000    15.000000
# 75%      44.750000    24.000000    18.000000
# max     628.000000   138.000000    23.000000

# %%
air_21.loc[air_21['O3'] > normal[2]].describe()
# Out:
#           측정소코드        SO2         CO         O3        NO2        PM10  \
# count      87.0  87.000000  87.000000  87.000000  87.000000   87.000000
# mean   111123.0   0.004379   0.490805   0.102425   0.019218   48.850575
# std         0.0   0.001003   0.077207   0.011285   0.006971   14.735283
# min    111123.0   0.002000   0.300000   0.091000   0.008000   28.000000
# 25%    111123.0   0.004000   0.500000   0.094000   0.014000   39.000000
# 50%    111123.0   0.004000   0.500000   0.098000   0.018000   45.000000
# 75%    111123.0   0.005000   0.500000   0.108000   0.022000   55.000000
# max    111123.0   0.007000   0.800000   0.137000   0.038000  100.000000
#
#             PM25       hour
# count  87.000000  87.000000
# mean   31.586207  16.275862
# std     6.810648   1.654379
# min    18.000000  12.000000
# 25%    26.000000  15.000000
# 50%    31.000000  16.000000
# 75%    35.500000  17.000000
# max    50.000000  21.000000

# %%
air_21.corr()
# Out:
#        측정소코드      측정일시       SO2        CO        O3       NO2      PM10  \
# 측정소코드    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 측정일시     NaN  1.000000 -0.155698 -0.089902 -0.099548 -0.059091 -0.165364
# SO2      NaN -0.155698  1.000000  0.338615  0.110768  0.329016  0.216044
# CO       NaN -0.089902  0.338615  1.000000 -0.462092  0.866890  0.310623
# O3       NaN -0.099548  0.110768 -0.462092  1.000000 -0.577542 -0.026716
# NO2      NaN -0.059091  0.329016  0.866890 -0.577542  1.000000  0.241157
# PM10     NaN -0.165364  0.216044  0.310623 -0.026716  0.241157  1.000000
# PM25     NaN -0.122028  0.378559  0.638507 -0.084630  0.517069  0.674715
#
#            PM25
# 측정소코드       NaN
# 측정일시  -0.122028
# SO2    0.378559
# CO     0.638507
# O3    -0.084630
# NO2    0.517069
# PM10   0.674715
# PM25   1.000000

# %%
weather_21['일시'] = pd.to_datetime(weather_21['일시'])
weather_22['일시'] = pd.to_datetime(weather_22['일시'])
weather_21['hour'] = weather_21['일시'].dt.hour
weather_21['일시'] = weather_21['일시'].dt.date
weather_22['hour'] = weather_22['일시'].dt.hour
weather_22['일시'] = weather_22['일시'].dt.date

# %%
List = list(air_21['측정일시'])
for i in range(len(List)):
    string = str(List[i])
    date = string[:8]
    hour = string[-2:]
    formatted = datetime.strptime(date,'%Y%m%d')
    formatted = formatted + timedelta(hours=int(hour))
    air_21['측정일시'][i] = formatted

air_21['측정일시'] = pd.to_datetime(air_21['측정일시'])
air_21['hour'] = air_21['측정일시'].dt.hour
air_21['측정일시'] = air_21['측정일시'].dt.date

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
air_21.isna().sum()
# Out:
# 지역         0
# 망          0
# 측정소코드      0
# 측정소명       0
# 측정일시       0
# SO2      112
# CO        80
# O3        97
# NO2       80
# PM10     105
# PM25      97
# 주소         0
# hour       0
# dtype: int64

# %%
air_drop = ['지역', '망', '측정소코드', '측정소명', '주소']
temporary2 = air_21.loc[air_21['SO2'].isnull()].drop(air_drop, axis=1)
temporary2.to_excel('temporary2.xlsx', index=False)
# Out:
# 측정일시     0
# SO2      0
# CO       0
# O3      17
# NO2      0
# PM10    28
# PM25    20
# hour     0
# dtype: int64

# %%
air_21.drop(air_drop, axis=1).corr()
# Out:
#            SO2        CO        O3       NO2      PM10      PM25      hour
# SO2   1.000000  0.338615  0.110768  0.329016  0.216044  0.378559  0.099395
# CO    0.338615  1.000000 -0.462092  0.866890  0.310623  0.638507 -0.033953
# O3    0.110768 -0.462092  1.000000 -0.577542 -0.026716 -0.084630  0.285126
# NO2   0.329016  0.866890 -0.577542  1.000000  0.241157  0.517069 -0.020159
# PM10  0.216044  0.310623 -0.026716  0.241157  1.000000  0.674715  0.027901
# PM25  0.378559  0.638507 -0.084630  0.517069  0.674715  1.000000  0.039338
# hour  0.099395 -0.033953  0.285126 -0.020159  0.027901  0.039338  1.000000

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 일단 ['지역', '망', '측정소코드', '측정소명', '주소']은 제거하는 걸로..
# 2. PM25는 PM10보다 SO2, CO, O3, NO2에 더 영향을 받는다. 그 중, CO와 NO2에는 영향을 많이 받는 편이다.
# 3. PM10과 PM25는 O3와는 상관이 없는 수준이다.
# 4. 결측치가 일부 존재하므로, 이를 어떻게 보간할 지 생각해보아야 한다.
# 5. CO와 NO2는 서로 강한 상관 관계를 가진다.
# 6. SO2는 모두 좋음 수치이다.
# 7. 약 42.7%의 O3 수치가 보통 이상의 수치를 지닌다.

# %% [markdown]
# #### [실습문제5] 날씨 데이터 알아보기
# * weather_21, weather_22 의 다양한 변수에 대하여 여러 그래프를 그려보고 인사이트를 도출해보세요.

# %%
weather_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8759 entries, 108 to 108
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점명            8759 non-null   object
#  1   일시             8759 non-null   object
#  2   기온(°C)         8759 non-null   float64
#  3   기온 QC플래그       0 non-null      float64
#  4   강수량(mm)        949 non-null    float64
#  5   강수량 QC플래그      1763 non-null   float64
#  6   풍속(m/s)        8757 non-null   float64
#  7   풍속 QC플래그       2 non-null      float64
#  8   풍향(16방위)       8757 non-null   float64
#  9   풍향 QC플래그       2 non-null      float64
#  10  습도(%)          8759 non-null   int64
#  11  습도 QC플래그       0 non-null      float64
#  12  증기압(hPa)       8759 non-null   float64
#  13  이슬점온도(°C)      8759 non-null   float64
#  14  현지기압(hPa)      8759 non-null   float64
#  15  현지기압 QC플래그     0 non-null      float64
#  16  해면기압(hPa)      8759 non-null   float64
#  17  해면기압 QC플래그     0 non-null      float64
#  18  일조(hr)         4791 non-null   float64
#  19  일조 QC플래그       3968 non-null   float64
#  20  일사(MJ/m2)      4791 non-null   float64
#  21  일사 QC플래그       3968 non-null   float64
#  22  적설(cm)         379 non-null    float64
#  23  3시간신적설(cm)     29 non-null     float64
#  24  전운량(10분위)      8757 non-null   float64
#  25  중하층운량(10분위)    8759 non-null   int64
#  26  운형(운형약어)       4947 non-null   object
#  27  최저운고(100m )    4547 non-null   float64
#  28  시정(10m)        8759 non-null   int64
#  29  지면상태(지면상태코드)   0 non-null      float64
#  30  현상번호(국내식)      2125 non-null   float64
#  31  지면온도(°C)       8754 non-null   float64
#  32  지면온도 QC플래그     24 non-null     float64
#  33  5cm 지중온도(°C)   8754 non-null   float64
#  34  10cm 지중온도(°C)  8754 non-null   float64
#  35  20cm 지중온도(°C)  8754 non-null   float64
#  36  30cm 지중온도(°C)  8754 non-null   float64
#  37  hour           8759 non-null   int64
# dtypes: float64(31), int64(4), object(3)
# memory usage: 2.6+ MB

# %%
weather_21.isna().sum()
# Out:
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         8759
# 강수량(mm)          7810
# 강수량 QC플래그        6996
# 풍속(m/s)             2
# 풍속 QC플래그         8757
# 풍향(16방위)            2
# 풍향 QC플래그         8757
# 습도(%)               0
# 습도 QC플래그         8759
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       8759
# 해면기압(hPa)           0
# 해면기압 QC플래그       8759
# 일조(hr)           3968
# 일조 QC플래그         4791
# 일사(MJ/m2)        3968
# 일사 QC플래그         4791
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 운형(운형약어)         3812
# 최저운고(100m )      4212
# 시정(10m)             0
# 지면상태(지면상태코드)     8759
# 현상번호(국내식)        6634
# 지면온도(°C)            5
# 지면온도 QC플래그       8735
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# hour                0
# dtype: int64

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
cols = ['기온(°C)','습도(%)', '이슬점온도(°C)',
       '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '증기압(hPa)',
       '현지기압(hPa)', '해면기압(hPa)', '일조(hr)', '일사(MJ/m2)', '적설(cm)', '전운량(10분위)',
       '중하층운량(10분위)', '최저운고(100m )', '시정(10m)', '지면온도(°C)', '5cm 지중온도(°C)',
       '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)']
for column in cols:
    plt.hist(weather_21[column], bins = 15, edgecolor = 'gray')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
drop_col = ['지점명', '지면상태(지면상태코드)', '현상번호(국내식)','3시간신적설(cm)','운형(운형약어)','지면상태(지면상태코드)',
           '기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그', '풍향 QC플래그',
          '습도 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그', '일조 QC플래그', '일사 QC플래그',
          '지면온도 QC플래그']
temporary = weather_21.loc[weather_21['일조(hr)'].isnull()].drop(drop_col, axis=1)
temporary.to_excel('temporary.xlsx', index=False)

# %%
temporary3 = weather_21.loc[(weather_21['일사(MJ/m2)'].isnull() | weather_21['일사 QC플래그'].isnull())
                           & ((weather_21['일사(MJ/m2)'].isnull() & weather_21['일사 QC플래그'].isnull()) == False)].drop(drop_col, axis=1)
temporary3.to_excel('temporary3.xlsx', index=False)

# %%
temporary4 = weather_21.loc[(weather_21['일조(hr)'].isnull() | weather_21['일조 QC플래그'].isnull())
                           & ((weather_21['일조(hr)'].isnull() & weather_21['일조 QC플래그'].isnull()) == False)].drop(drop_col, axis=1)
temporary4.to_excel('temporary4.xlsx', index=False)

# %%
temporary = weather_21.loc[weather_21['적설(cm)'].notnull()].drop(drop_col, axis=1)
temporary.to_excel('temporary.xlsx', index=False)

# %%
weather_21['일사 QC플래그'].unique()
# Out:
# array([ 9., nan])

# %%
weather_21['일조 QC플래그'].unique()
# Out:
# array([ 9., nan])

# %%
QC_cols = ['기온 QC플래그', '강수량 QC플래그', '풍속 QC플래그', '풍향 QC플래그',
          '습도 QC플래그', '현지기압 QC플래그', '해면기압 QC플래그', '일조 QC플래그', '일사 QC플래그',
          '지면온도 QC플래그']

for column in QC_cols:
    print(f'{column} : ', weather_21[column].unique())
print('-'*30)
for column in QC_cols:
    print(f'{column} : ', weather_22[column].unique())
# Out:
# 기온 QC플래그 :  [nan]
# 강수량 QC플래그 :  [nan  9.]
# 풍속 QC플래그 :  [nan  9.]
# 풍향 QC플래그 :  [nan  9.]
# 습도 QC플래그 :  [nan]
# 현지기압 QC플래그 :  [nan]
# 해면기압 QC플래그 :  [nan]
# 일조 QC플래그 :  [ 9. nan]
# 일사 QC플래그 :  [ 9. nan]
# 지면온도 QC플래그 :  [nan  0.  9.]
# ------------------------------
# 기온 QC플래그 :  [nan]
# 강수량 QC플래그 :  [nan  9.]
# 풍속 QC플래그 :  [nan]
# 풍향 QC플래그 :  [nan]
# 습도 QC플래그 :  [nan]
# 현지기압 QC플래그 :  [nan]
# 해면기압 QC플래그 :  [nan]
# 일조 QC플래그 :  [ 9. nan]
# 일사 QC플래그 :  [ 9. nan]
# 지면온도 QC플래그 :  [nan  0.]

# %%
weather_21['지면온도 QC플래그'].loc[weather_21['지면온도 QC플래그'] == 0.].count()
# Out:
# 19

# %%
weather_21['일시'] = pd.to_datetime(weather_21['일시'])
weather_22['일시'] = pd.to_datetime(weather_22['일시'])
weather_21['hour'] = weather_21['일시'].dt.hour
weather_21['일시'] = weather_21['일시'].dt.date
weather_22['hour'] = weather_22['일시'].dt.hour
weather_22['일시'] = weather_22['일시'].dt.date

# %%
# temporary = weather_22.loc[weather_22['일조(hr)'].isnull()].drop(drop_col, axis=1)
# temporary.to_excel('temporary.xlsx', index=False)
temporary2 = weather_22.loc[weather_22['일사(MJ/m2)'].isnull()].drop(drop_col, axis=1)
temporary2.to_excel('temporary2.xlsx', index=False)

# %%
temporary3 = weather_21.loc[weather_21['강수량(mm)'].isnull() & weather_21['강수량 QC플래그'].notnull()].drop(drop_col, axis=1)
temporary3.to_excel('temporary3.xlsx', index=False)

# %%
weather_21.isna().sum()
# Out:
# 지점명                 0
# 일시                  0
# 기온(°C)              0
# 기온 QC플래그         8759
# 강수량(mm)          7810
# 강수량 QC플래그        6996
# 풍속(m/s)             2
# 풍속 QC플래그         8757
# 풍향(16방위)            2
# 풍향 QC플래그         8757
# 습도(%)               0
# 습도 QC플래그         8759
# 증기압(hPa)            0
# 이슬점온도(°C)           0
# 현지기압(hPa)           0
# 현지기압 QC플래그       8759
# 해면기압(hPa)           0
# 해면기압 QC플래그       8759
# 일조(hr)           3968
# 일조 QC플래그         4791
# 일사(MJ/m2)        3968
# 일사 QC플래그         4791
# 적설(cm)           8380
# 3시간신적설(cm)       8730
# 전운량(10분위)           2
# 중하층운량(10분위)         0
# 운형(운형약어)         3812
# 최저운고(100m )      4212
# 시정(10m)             0
# 지면상태(지면상태코드)     8759
# 현상번호(국내식)        6634
# 지면온도(°C)            5
# 지면온도 QC플래그       8735
# 5cm 지중온도(°C)        5
# 10cm 지중온도(°C)       5
# 20cm 지중온도(°C)       5
# 30cm 지중온도(°C)       5
# hour                0
# dtype: int64

# %%
cols2 = ['시정(10m)', '지면온도(°C)', '5cm 지중온도(°C)', '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)', 'hour']
temp = weather_21.drop(drop_col, axis=1)
temp.drop(cols2, axis=1).corr()
# Out:
#                기온(°C)   강수량(mm)   풍속(m/s)  풍향(16방위)     습도(%)  증기압(hPa)  \
# 기온(°C)       1.000000 -0.009142 -0.068998 -0.181061  0.145404  0.881615
# 강수량(mm)     -0.009142  1.000000  0.195771 -0.031724  0.254056  0.067937
# 풍속(m/s)     -0.068998  0.195771  1.000000  0.172669 -0.285136 -0.147224
# 풍향(16방위)    -0.181061 -0.031724  0.172669  1.000000 -0.200744 -0.188806
# 습도(%)        0.145404  0.254056 -0.285136 -0.200744  1.000000  0.450867
# 증기압(hPa)     0.881615  0.067937 -0.147224 -0.188806  0.450867  1.000000
# 이슬점온도(°C)    0.926402  0.075776 -0.168898 -0.231501  0.501853  0.946841
# 현지기압(hPa)   -0.680025 -0.114330 -0.046459  0.043715 -0.359807 -0.712216
# 해면기압(hPa)   -0.707822 -0.112065 -0.041041  0.051917 -0.354960 -0.732223
# 일조(hr)      -0.030577 -0.047097  0.175146  0.116463 -0.561533 -0.235512
# 일사(MJ/m2)    0.259726 -0.151331  0.188221  0.075342 -0.505902  0.009038
# 적설(cm)       0.273284  0.300225 -0.095575 -0.103654  0.370726  0.377134
# 전운량(10분위)    0.307568  0.101299 -0.026692 -0.176713  0.362256  0.356878
# 중하층운량(10분위)  0.153382  0.181165  0.036578 -0.094902  0.379977  0.239803
# 최저운고(100m )  0.080681 -0.178925 -0.104431 -0.076933 -0.336348 -0.067908
#
#              이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)    일조(hr)  일사(MJ/m2)    적설(cm)  \
# 기온(°C)        0.926402  -0.680025  -0.707822 -0.030577   0.259726  0.273284
# 강수량(mm)       0.075776  -0.114330  -0.112065 -0.047097  -0.151331  0.300225
# 풍속(m/s)      -0.168898  -0.046459  -0.041041  0.175146   0.188221 -0.095575
# 풍향(16방위)     -0.231501   0.043715   0.051917  0.116463   0.075342 -0.103654
# 습도(%)         0.501853  -0.359807  -0.354960 -0.561533  -0.505902  0.370726
# 증기압(hPa)      0.946841  -0.712216  -0.732223 -0.235512   0.009038  0.377134
# 이슬점온도(°C)     1.000000  -0.726512  -0.748944 -0.257635   0.012966  0.349052
# 현지기압(hPa)    -0.726512   1.000000   0.999241  0.238842  -0.009147 -0.300733
# 해면기압(hPa)    -0.748944   0.999241   1.000000  0.232820  -0.021364 -0.307171
# 일조(hr)       -0.257635   0.238842   0.232820  1.000000   0.726199  0.033302
# 일사(MJ/m2)     0.012966  -0.009147  -0.021364  0.726199   1.000000 -0.080727
# 적설(cm)        0.349052  -0.300733  -0.307171  0.033302  -0.080727  1.000000
# 전운량(10분위)     0.397847  -0.358584  -0.362082 -0.681275  -0.341380  0.057089
# 중하층운량(10분위)   0.269643  -0.306983  -0.304160 -0.601412  -0.324635  0.135481
# 최저운고(100m )  -0.053618   0.196248   0.185978  0.036772   0.009990 -0.283868
#
#              전운량(10분위)  중하층운량(10분위)  최저운고(100m )
# 기온(°C)        0.307568     0.153382     0.080681
# 강수량(mm)       0.101299     0.181165    -0.178925
# 풍속(m/s)      -0.026692     0.036578    -0.104431
# 풍향(16방위)     -0.176713    -0.094902    -0.076933
# 습도(%)         0.362256     0.379977    -0.336348
# 증기압(hPa)      0.356878     0.239803    -0.067908
# 이슬점온도(°C)     0.397847     0.269643    -0.053618
# 현지기압(hPa)    -0.358584    -0.306983     0.196248
# 해면기압(hPa)    -0.362082    -0.304160     0.185978
# 일조(hr)       -0.681275    -0.601412     0.036772
# 일사(MJ/m2)    -0.341380    -0.324635     0.009990
# 적설(cm)        0.057089     0.135481    -0.283868
# 전운량(10분위)     1.000000     0.748735    -0.061855
# 중하층운량(10분위)   0.748735     1.000000    -0.088167
# 최저운고(100m )  -0.061855    -0.088167     1.000000

# %%
# temporary4 = weather_21.loc[weather_21['최저운고(100m )'].isnull()].drop(drop_col, axis=1) 4212개
# 그 중에서 전운량과 중하층운량이 둘 중 하나가 null인 것은 1개
# temporary4.to_excel('temporary4.xlsx', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4212 entries, 108 to 108
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   일시             4212 non-null   object
#  1   기온(°C)         4212 non-null   float64
#  2   강수량(mm)        48 non-null     float64
#  3   풍속(m/s)        4210 non-null   float64
#  4   풍향(16방위)       4210 non-null   float64
#  5   습도(%)          4212 non-null   int64
#  6   증기압(hPa)       4212 non-null   float64
#  7   이슬점온도(°C)      4212 non-null   float64
#  8   현지기압(hPa)      4212 non-null   float64
#  9   해면기압(hPa)      4212 non-null   float64
#  10  일조(hr)         1919 non-null   float64
#  11  일사(MJ/m2)      1919 non-null   float64
#  12  적설(cm)         207 non-null    float64
#  13  전운량(10분위)      4211 non-null   float64
#  14  중하층운량(10분위)    4212 non-null   int64
#  15  최저운고(100m )    0 non-null      float64
#  16  시정(10m)        4212 non-null   int64
#  17  지면온도(°C)       4209 non-null   float64
#  18  5cm 지중온도(°C)   4209 non-null   float64
#  19  10cm 지중온도(°C)  4209 non-null   float64
#  20  20cm 지중온도(°C)  4209 non-null   float64
#  21  30cm 지중온도(°C)  4209 non-null   float64
#  22  hour           4212 non-null   int64
# dtypes: float64(18), int64(4), object(1)
# memory usage: 789.8+ KB

# %%
# temporary5 = weather_21.loc[weather_21['최저운고(100m )'].notnull()].drop(drop_col, axis=1) 4547개
# temporary5.to_excel('temporary5.xlsx', index=False)
weather_21.loc[weather_21['최저운고(100m )'].notnull()].drop(drop_col, axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4547 entries, 108 to 108
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   일시             4547 non-null   object
#  1   기온(°C)         4547 non-null   float64
#  2   강수량(mm)        901 non-null    float64
#  3   풍속(m/s)        4547 non-null   float64
#  4   풍향(16방위)       4547 non-null   float64
#  5   습도(%)          4547 non-null   int64
#  6   증기압(hPa)       4547 non-null   float64
#  7   이슬점온도(°C)      4547 non-null   float64
#  8   현지기압(hPa)      4547 non-null   float64
#  9   해면기압(hPa)      4547 non-null   float64
#  10  일조(hr)         2872 non-null   float64
#  11  일사(MJ/m2)      2872 non-null   float64
#  12  적설(cm)         172 non-null    float64
#  13  전운량(10분위)      4546 non-null   float64
#  14  중하층운량(10분위)    4547 non-null   int64
#  15  최저운고(100m )    4547 non-null   float64
#  16  시정(10m)        4547 non-null   int64
#  17  지면온도(°C)       4545 non-null   float64
#  18  5cm 지중온도(°C)   4545 non-null   float64
#  19  10cm 지중온도(°C)  4545 non-null   float64
#  20  20cm 지중온도(°C)  4545 non-null   float64
#  21  30cm 지중온도(°C)  4545 non-null   float64
#  22  hour           4547 non-null   int64
# dtypes: float64(18), int64(4), object(1)
# memory usage: 852.6+ KB

# %%
weather_21.describe()
# Out:
#             기온(°C)  기온 QC플래그     강수량(mm)  강수량 QC플래그      풍속(m/s)  풍속 QC플래그  \
# count  8759.000000       0.0  949.000000     1763.0  8757.000000       2.0
# mean     13.739194       NaN    1.250263        9.0     2.311328       9.0
# std      10.894786       NaN    3.398801        0.0     1.120906       0.0
# min     -18.500000       NaN    0.000000        9.0     0.000000       9.0
# 25%       6.000000       NaN    0.000000        9.0     1.500000       9.0
# 50%      14.600000       NaN    0.100000        9.0     2.200000       9.0
# 75%      22.600000       NaN    1.100000        9.0     2.900000       9.0
# max      36.300000       NaN   64.700000        9.0     8.300000       9.0
#
#           풍향(16방위)  풍향 QC플래그        습도(%)  습도 QC플래그     증기압(hPa)    이슬점온도(°C)  \
# count  8757.000000       2.0  8759.000000       0.0  8759.000000  8759.000000
# mean    169.658559       9.0    65.589223       NaN    12.631236     6.842094
# std     107.549684       0.0    18.394276       NaN     8.282075    11.736897
# min       0.000000       9.0    19.000000       NaN     0.700000   -27.000000
# 25%      50.000000       9.0    51.000000       NaN     5.900000    -0.400000
# 50%     200.000000       9.0    66.000000       NaN     9.700000     6.600000
# 75%     270.000000       9.0    80.000000       NaN    19.900000    17.400000
# max     360.000000       9.0   100.000000       NaN    32.200000    25.300000
#
#          현지기압(hPa)  현지기압 QC플래그    해면기압(hPa)  해면기압 QC플래그       일조(hr)  \
# count  8759.000000         0.0  8759.000000         0.0  4791.000000
# mean   1006.046603         NaN  1016.280317         NaN     0.458380
# std       7.928167         NaN     8.311602         NaN     0.438788
# min     986.900000         NaN   996.500000         NaN     0.000000
# 25%     999.800000         NaN  1009.700000         NaN     0.000000
# 50%    1006.300000         NaN  1016.400000         NaN     0.400000
# 75%    1012.000000         NaN  1022.500000         NaN     1.000000
# max    1025.800000         NaN  1037.400000         NaN     1.000000
#
#        일조 QC플래그    일사(MJ/m2)  일사 QC플래그      적설(cm)  3시간신적설(cm)    전운량(10분위)  \
# count    3968.0  4791.000000    3968.0  379.000000   29.000000  8757.000000
# mean        9.0     1.076706       9.0    1.397625    0.962069     4.960489
# std         0.0     0.966440       0.0    1.357390    1.424132     3.929256
# min         9.0     0.000000       9.0    0.000000    0.000000     0.000000
# 25%         9.0     0.230000       9.0    0.400000    0.000000     0.000000
# 50%         9.0     0.790000       9.0    0.900000    0.200000     6.000000
# 75%         9.0     1.800000       9.0    1.850000    0.900000     9.000000
# max         9.0     3.740000       9.0    5.100000    4.400000    10.000000
#
#        중하층운량(10분위)  최저운고(100m )      시정(10m)  지면상태(지면상태코드)     현상번호(국내식)  \
# count  8759.000000  4547.000000  8759.000000           0.0  2.125000e+03
# mean      3.033565    15.161425  1719.765384           NaN  1.367177e+04
# std       3.452846    13.537921   521.130959           NaN  4.170156e+05
# min       0.000000     1.000000    33.000000           NaN  1.000000e+00
# 25%       0.000000     7.000000  1719.000000           NaN  5.000000e+00
# 50%       1.000000    10.000000  2000.000000           NaN  1.900000e+01
# 75%       6.000000    16.000000  2000.000000           NaN  1.901000e+03
# max      10.000000    76.000000  2000.000000           NaN  1.916020e+07
#
#           지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# count  8754.000000    24.00000   8754.000000    8754.000000    8754.000000
# mean     14.734304     1.87500     15.128581      14.555118      14.533276
# std      12.042066     3.73366     10.175582      10.044423       9.739277
# min     -12.700000     0.00000     -4.700000      -4.600000      -3.000000
# 25%       4.300000     0.00000      5.900000       5.500000       5.600000
# 50%      15.400000     0.00000     15.400000      14.700000      14.600000
# 75%      23.600000     0.00000     24.100000      23.500000      23.400000
# max      56.800000     9.00000     35.700000      33.700000      31.900000
#
#        30cm 지중온도(°C)         hour
# count    8754.000000  8759.000000
# mean       14.827633    11.501313
# std         9.360493     6.921886
# min        -0.800000     0.000000
# 25%         6.300000     6.000000
# 50%        15.100000    12.000000
# 75%        23.600000    17.500000
# max        30.600000    23.000000

# %%
temporary6 = weather_21.loc[(weather_21['최저운고(100m )'].notnull()) &
              (weather_21['전운량(10분위)'].isnull() | weather_21['중하층운량(10분위)'].isnull())].drop(drop_col, axis=1)
temporary6.to_excel('temporary6.xlsx', index=False)

# %%
weather_21.loc[(weather_21['최저운고(100m )'].isnull()) &
              (weather_21['전운량(10분위)'].isnull() | weather_21['중하층운량(10분위)'].isnull())].drop(drop_col, axis=1)
# Out:
#              일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 지점
# 108  2021-08-14    27.3      NaN      3.1      70.0     57      20.6
#
#      이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)  \
# 지점
# 108       18.0      998.6     1008.2     0.8       0.37     NaN        NaN
#
#      중하층운량(10분위)  최저운고(100m )  시정(10m)  지면온도(°C)  5cm 지중온도(°C)  10cm 지중온도(°C)  \
# 지점
# 108            0          NaN     2000      27.8          29.3           28.7
#
#      20cm 지중온도(°C)  30cm 지중온도(°C)  hour
# 지점
# 108           28.0           27.5    19

# %%
weather_21.loc[(weather_21['최저운고(100m )'].isnull()) &
              (weather_21['전운량(10분위)'].isnull() & weather_21['중하층운량(10분위)'].isnull())].drop(drop_col, axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   일시             0 non-null      object
#  1   기온(°C)         0 non-null      float64
#  2   강수량(mm)        0 non-null      float64
#  3   풍속(m/s)        0 non-null      float64
#  4   풍향(16방위)       0 non-null      float64
#  5   습도(%)          0 non-null      int64
#  6   증기압(hPa)       0 non-null      float64
#  7   이슬점온도(°C)      0 non-null      float64
#  8   현지기압(hPa)      0 non-null      float64
#  9   해면기압(hPa)      0 non-null      float64
#  10  일조(hr)         0 non-null      float64
#  11  일사(MJ/m2)      0 non-null      float64
#  12  적설(cm)         0 non-null      float64
#  13  전운량(10분위)      0 non-null      float64
#  14  중하층운량(10분위)    0 non-null      int64
#  15  최저운고(100m )    0 non-null      float64
#  16  시정(10m)        0 non-null      int64
#  17  지면온도(°C)       0 non-null      float64
#  18  5cm 지중온도(°C)   0 non-null      float64
#  19  10cm 지중온도(°C)  0 non-null      float64
#  20  20cm 지중온도(°C)  0 non-null      float64
#  21  30cm 지중온도(°C)  0 non-null      float64
#  22  hour           0 non-null      int64
# dtypes: float64(18), int64(4), object(1)
# memory usage: 0.0+ bytes

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.(집중! 데이터 분포의 모양을 잘 살펴봐주세요.)
# 1. 온도, 습도, 이슬점 온도는 서로 비슷한 형태를 지님.
# 2. 현지기압과 해면기압은 유사한 그래프 모양을 지님.
# 3. 일조, 일사가 결측치 인 경우 2021-01-07 11:00~13:00 제외하고 모두 밤이다. (weather_22는 밤일때 모두 결측치를 가짐. 낮일때는 결측치를 갖지 않음.)
# 4. 일조, 일사 QC플래그는 모두 9 or nan 값을 지님. 9일때는 모두 일조, 일사 결측치인 날과 같다.
# 5. 일조 + 일조 QC 플래그, 일사 + 일사 QC 플래그 = 전체 데이터. 일조값이 있을 때는 일조 QC 플래그가 없고,
# QC 플래그가 있으면 일조값이 없음. -> 결측치 유무만 알려주고 정상인지 오류인지는 알려주지 않음.
# 결측치를 처리한다면 QC 그래프는 사용하지 않을듯.
# QC 플래그 : (0. 정상, 1. 오류, 9. 결측) 
# 6. QC 플래그들의 unique를 확인한 결과 모두 9 or nan 값을 지님.
# 지면온도 QC 플래그는 0인 값을 지닌 row가 있지만 19개 정도로, 이 또한 정상을 의미하므로 특별한 의미를 가지지 않는 것 같다.
# 눈이 올 때가 과연 미세먼지의 영향을 끼칠까? 전운량과 중하층운량은?
# 최저운고 : 운량 5/8 관측값이 있을 경우 이들 값중 최저 운고값 (항공에서 측정함)
