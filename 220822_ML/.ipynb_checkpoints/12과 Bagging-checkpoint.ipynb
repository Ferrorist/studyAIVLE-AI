# %% [markdown]
# # Ensemble : Bagging

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) import

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 전처리
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 모델링
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import * 
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### (2) 데이터 준비

# %% [markdown]
# * 변수설명
#     * COLLEGE : 대학 졸업여부
#     * INCOME : 연수입
#     * OVERAGE : 월평균 초과사용 시간(분)
#     * LEFTOVER : 월평균 잔여시간비율(%)
#     * HOUSE : 집값
#     * HANDSET_PRICE : 스마트폰 가격
#     * OVER_15MINS_CALLS_PER_MONTH : 월평균 장기통화(15분이상) 횟수
#     * AVERAGE_CALL_DURATION : 평균 통화 시간
#     * REPORTED_SATISFACTION : 만족도 설문조사 결과
#     * REPORTED_USAGE_LEVEL : 사용도 자가진단 결과
#     * CONSIDERING_CHANGE_OF_PLAN : 향후 변경계획 설문조사 결과
#     * CHURN : 이탈(번호이동) 여부 (1-이탈, 0-잔류, Target 변수)

# %%
# 데이터를 불러옵시다.
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv'
data = pd.read_csv(path)
data = data.sample(5000, random_state = 2022)
data['CHURN'] = data['CHURN'].map({'LEAVE':1, 'STAY':0})
data.head()
# Out:
#           id  COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 3178    3179        0  119512       51        31  248566            229
# 14926  14927        1  142144      192        15  774317            581
# 15116  15117        1  142308        0        79  306426            497
# 12733  12734        1  113385        0         0  333599            819
# 14032  14033        1   90348      209        10  637286            360
#
#        OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION  \
# 3178                             5                      2
# 14926                           29                      4
# 15116                            1                      1
# 12733                            1                      6
# 14032                           26                      4
#
#       REPORTED_SATISFACTION REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  \
# 3178               very_sat            very_high                considering
# 14926                 unsat          very_little              never_thought
# 15116                   sat               little                considering
# 12733            very_unsat            very_high                considering
# 14032                 unsat               little   actively_looking_into_it
#
#        CHURN
# 3178       1
# 14926      1
# 15116      0
# 12733      1
# 14032      0

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) 데이터 정리

# %%
drop_cols = ['id']
data.drop(drop_cols, axis = 1, inplace = True )

# %% [markdown]
# ### (2) 데이터분할1 : x, y 나누기

# %%
target = 'CHURN'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) NA 조치

# %% [markdown]
# ### (4) 가변수화

# %%
dumm_cols = ['REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# %% [markdown]
# ### (5) 데이터분할2 : train : validation

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 2022)

# %% [markdown]
# ## 3.모델링 : 랜덤포레스트

# %%
# 모델 선언
model = RandomForestClassifier(n_estimators = 5, max_depth = 3)

# %%
# 학습
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=5)

# %%
# 예측
pred = model.predict(x_val)

# %%
# 평가
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70       769
#            1       0.70      0.58      0.63       731
#
#     accuracy                           0.67      1500
#    macro avg       0.68      0.67      0.67      1500
# weighted avg       0.67      0.67      0.67      1500

# %% [markdown]
# ## 4.시각화와 변수중요도

# %% [markdown]
# ### (1) 모델의 내부를 살펴봅시다.

# %%
# 5개 decision tree
model.estimators_
# Out:
# [DecisionTreeClassifier(max_depth=3, max_features='auto',
#                         random_state=1420787118),
#  DecisionTreeClassifier(max_depth=3, max_features='auto', random_state=404329844),
#  DecisionTreeClassifier(max_depth=3, max_features='auto',
#                         random_state=1691168291),
#  DecisionTreeClassifier(max_depth=3, max_features='auto',
#                         random_state=1493487749),
#  DecisionTreeClassifier(max_depth=3, max_features='auto', random_state=396729515)]

# %%
# 각 트리별로 시각화 할 수 있다.
plt.figure(figsize=(20,6))
plot_tree(model.estimators_[0], 
               feature_names = x_train.columns,
               class_names= ['LEAVE','STAY'], 
               filled = True, fontsize = 8);
plot_tree(model.estimators_[1], 
               feature_names = x_train.columns,
               class_names= ['LEAVE','STAY'], 
               filled = True, fontsize = 8);
plot_tree(model.estimators_[2], 
               feature_names = x_train.columns,
               class_names= ['LEAVE','STAY'], 
               filled = True, fontsize = 8);

# %% [markdown]
# ### (2) 변수 중요도

# %%
# 변수 중요도
print(x_train.columns)
print(model.feature_importances_)
# Out:
# Index(['COLLEGE', 'INCOME', 'OVERAGE', 'LEFTOVER', 'HOUSE', 'HANDSET_PRICE',
#        'OVER_15MINS_CALLS_PER_MONTH', 'AVERAGE_CALL_DURATION',
#        'REPORTED_SATISFACTION_sat', 'REPORTED_SATISFACTION_unsat',
#        'REPORTED_SATISFACTION_very_sat', 'REPORTED_SATISFACTION_very_unsat',
#        'REPORTED_USAGE_LEVEL_high', 'REPORTED_USAGE_LEVEL_little',
#        'REPORTED_USAGE_LEVEL_very_high', 'REPORTED_USAGE_LEVEL_very_little',
#        'CONSIDERING_CHANGE_OF_PLAN_considering',
#        'CONSIDERING_CHANGE_OF_PLAN_never_thought',
#        'CONSIDERING_CHANGE_OF_PLAN_no', 'CONSIDERING_CHANGE_OF_PLAN_perhaps'],
#       dtype='object')
# [0.00129111 0.02503008 0.30360805 0.02366849 0.35632832 0.06618417
#  0.17019576 0.03628197 0.00216644 0.00310285 0.         0.00439424
#  0.         0.         0.         0.00064035 0.00577449 0.00133369
#  0.         0.        ]

# %% [markdown]
# * 변수중요도 그래프 그리기 함수 만들기

# %%
def plot_feature_importance(importance, names):
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df.reset_index(drop=True, inplace = True)

    plt.figure(figsize=(10,8))
    sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    plt.grid()

    return fi_df

# %%
result = plot_feature_importance(model.feature_importances_, x_train.columns)

# %% [markdown]
# ## 5.실습: random forest 튜닝
#
# * grid search를 수행합니다.
#     * ① n_estimators 의 갯수를 5 ~ 200까지 5개씩 증가시켜가며 튜닝해 봅시다.
#     * ② max_features를 1 ~ feature갯수까지 1씩 증가시켜가며 튜닝해 봅시다.
#     * ③ n_estimators, max_features를 동시에 튜닝.
#
# * 모델링 후 cv 평가 결과를 차트로 그려봅시다.
# * 튜닝된 모델로 부터 변수중요도를 뽑아 봅시다.

# %% [markdown]
# ### (1) n_estimators 튜닝

# %%
params = {'n_estimators' : range(5,201,5)} # 100~200개 정도가 적당함.
#트리가 많아진다고 모델이 복잡해지지 않고, 오히려 과적합을 방지한다. 평균을 쓰기 때문.
# 과적합을 피하기 위햇 Random Forest 기법을 사용했다 -> True
model = RandomForestClassifier()
model_rf1 = GridSearchCV(model, params, cv=10)

# %%
model_rf1.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': range(5, 201, 5)})

# %%
pred1 = model_rf1.predict(x_val)

# %%
print(classification_report(y_val, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       769
#            1       0.71      0.69      0.70       731
#
#     accuracy                           0.71      1500
#    macro avg       0.71      0.71      0.71      1500
# weighted avg       0.71      0.71      0.71      1500

# %%
# 튜닝 결과를 그래프로 그리기
result = pd.DataFrame(model_rf1.cv_results_)
temp = result.loc[:, ['param_n_estimators', 'mean_test_score']]

plt.figure(figsize=(12,8))
plt.plot('param_n_estimators', 'mean_test_score', data=temp)
plt.grid()
plt.show()

# %% [markdown]
# ### (2) max_features 튜닝

# %%
mSize = x_train.columns.size

# %%
params2 = {'max_features': range(1,mSize+1)}
model2 = RandomForestClassifier()
model_rf2 = RandomizedSearchCV(model2, params2, cv=10)

# %%
model_rf2.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'max_features': range(1, 21)})

# %%
pred2 = model_rf2.predict(x_val)

# %%
print(classification_report(y_val, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       769
#            1       0.70      0.72      0.71       731
#
#     accuracy                           0.72      1500
#    macro avg       0.72      0.72      0.72      1500
# weighted avg       0.72      0.72      0.72      1500

# %%
result2 = pd.DataFrame(model_rf2.cv_results_)
temp2 = result2.loc[:, ['param_max_features', 'mean_test_score']]

plt.figure(figsize=(12,8))
plt.plot('param_max_features', 'mean_test_score', data=temp2)
plt.grid()
plt.show()

# %% [markdown]
# * 변수 중요도

# %% [markdown]
# ### (3) n_estimators와 max_features를 한꺼번에 튜닝

# %%
params3 = {'n_estimators' : range(5,201,5), 'max_features': range(1,mSize+1)}
model3 = RandomForestClassifier()
model_rf3 = RandomizedSearchCV(model3, params3, cv=10)

# %%
model_rf3.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'max_features': range(1, 21),
#                                         'n_estimators': range(5, 201, 5)})

# %%
pred3 = model_rf3.predict(x_val)

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       769
#            1       0.69      0.71      0.70       731
#
#     accuracy                           0.71      1500
#    macro avg       0.71      0.71      0.71      1500
# weighted avg       0.71      0.71      0.71      1500
