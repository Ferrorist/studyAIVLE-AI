# %% [markdown]
# ## test data 데이터 처리하기
# - 단, rows는 제거하지 않는 방법으로 처리하여야 한다.

# %%
#라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst
import statsmodels.api as sm

import warnings
warnings.filterwarnings(action='ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import * # scaler

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import * 
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier, plot_tree

# %%
import joblib

# %%
data = pd.read_csv('test_dataset_v01.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  url_len  url_num_hyphens_dom  url_path_len  url_domain_len  \
# 0           0       97                    0          80.0            17.0
# 1           1       37                    0          22.0            15.0
# 2           2       44                    0           NaN            20.0
# 3           3       40                    0          14.0            26.0
# 4           4       43                    2           NaN            26.0
#
#    url_hostname_len  url_num_dots  url_num_underscores  url_query_len  \
# 0              17.0             4                    0              0
# 1              15.0             3                    1              0
# 2              20.0             3                    3              0
# 3              26.0             2                    0              0
# 4              26.0             2                    0              0
#
#    url_num_query_para  ...  html_num_tags('iframe')  html_num_tags('script')  \
# 0                   0  ...                        0                      5.0
# 1                   0  ...                        1                      NaN
# 2                   0  ...                        0                      6.0
# 3                   0  ...                        0                      NaN
# 4                   0  ...                        0                      NaN
#
#    html_num_tags('embed')  html_num_tags('object')  html_num_tags('div')  \
# 0                       0                        0                    12
# 1                       0                        0                   158
# 2                       3                        3                    34
# 3                       0                        0                    29
# 4                       0                        0                    41
#
#    html_num_tags('head')  html_num_tags('body')  html_num_tags('form')  \
# 0                      1                      1                    1.0
# 1                      1                      1                    NaN
# 2                      1                      1                    0.0
# 3                      1                      1                    1.0
# 4                      1                      1                    NaN
#
#    html_num_tags('a')  html_num_tags('applet')
# 0                 3.0                        0
# 1                 NaN                        0
# 2               136.0                        0
# 3                 2.0                        0
# 4                 NaN                        0
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2441 entries, 0 to 2440
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               2441 non-null   int64
#  1   url_len                  2441 non-null   int64
#  2   url_num_hyphens_dom      2441 non-null   int64
#  3   url_path_len             1975 non-null   float64
#  4   url_domain_len           1975 non-null   float64
#  5   url_hostname_len         1978 non-null   float64
#  6   url_num_dots             2441 non-null   int64
#  7   url_num_underscores      2441 non-null   int64
#  8   url_query_len            2441 non-null   int64
#  9   url_num_query_para       2441 non-null   int64
#  10  url_ip_present           2441 non-null   int64
#  11  url_entropy              2441 non-null   float64
#  12  url_chinese_present      2441 non-null   int64
#  13  url_port                 2441 non-null   int64
#  14  html_num_tags('iframe')  2441 non-null   int64
#  15  html_num_tags('script')  1974 non-null   float64
#  16  html_num_tags('embed')   2441 non-null   int64
#  17  html_num_tags('object')  2441 non-null   int64
#  18  html_num_tags('div')     2441 non-null   int64
#  19  html_num_tags('head')    2441 non-null   int64
#  20  html_num_tags('body')    2441 non-null   int64
#  21  html_num_tags('form')    1974 non-null   float64
#  22  html_num_tags('a')       1980 non-null   float64
#  23  html_num_tags('applet')  2441 non-null   int64
# dtypes: float64(7), int64(17)
# memory usage: 457.8 KB

# %% [markdown]
# ### 결측치 조치

# %%
data.isna().sum()
# Out:
# Unnamed: 0                   0
# url_len                      0
# url_num_hyphens_dom          0
# url_path_len               466
# url_domain_len             466
# url_hostname_len           463
# url_num_dots                 0
# url_num_underscores          0
# url_query_len                0
# url_num_query_para           0
# url_ip_present               0
# url_entropy                  0
# url_chinese_present          0
# url_port                     0
# html_num_tags('iframe')      0
# html_num_tags('script')    467
# html_num_tags('embed')       0
# html_num_tags('object')      0
# html_num_tags('div')         0
# html_num_tags('head')        0
# html_num_tags('body')        0
# html_num_tags('form')      467
# html_num_tags('a')         461
# html_num_tags('applet')      0
# dtype: int64

# %%
data.loc[data['url_path_len'].isnull()].head(30)
# Out:
#      Unnamed: 0  url_len  url_num_hyphens_dom  url_path_len  url_domain_len  \
# 2             2       44                    0           NaN            20.0
# 4             4       43                    2           NaN            26.0
# 19           19       45                    1           NaN            12.0
# 21           21       22                    1           NaN             NaN
# 26           26       33                    0           NaN            17.0
# 32           32      141                    0           NaN            15.0
# 33           33       37                    0           NaN            22.0
# 42           42       73                    0           NaN             NaN
# 46           46       40                    0           NaN            19.0
# 49           49      101                    0           NaN            15.0
# 52           52       95                    0           NaN             NaN
# 53           53       34                    0           NaN            15.0
# 56           56       13                    0           NaN            13.0
# 59           59       39                    1           NaN            29.0
# 60           60       34                    0           NaN            12.0
# 62           62       38                    0           NaN            21.0
# 74           74       33                    2           NaN             NaN
# 77           77       37                    0           NaN            18.0
# 82           82       32                    1           NaN            22.0
# 88           88       31                    0           NaN            17.0
# 89           89       51                    0           NaN            14.0
# 108         108       70                    0           NaN             NaN
# 115         115       34                    0           NaN            13.0
# 122         122       85                    0           NaN            13.0
# 124         124       25                    0           NaN            17.0
# 127         127       32                    0           NaN             NaN
# 129         129       96                    0           NaN            23.0
# 131         131       34                    0           NaN            10.0
# 133         133       55                    0           NaN             NaN
# 137         137       17                    0           NaN            13.0
#
#      url_hostname_len  url_num_dots  url_num_underscores  url_query_len  \
# 2                20.0             3                    3              0
# 4                26.0             2                    0              0
# 19               12.0             4                    0              0
# 21                NaN             2                    0              0
# 26               17.0             4                    0              0
# 32               15.0             6                    0              0
# 33               22.0             2                    0              0
# 42               14.0             3                    1              0
# 46               19.0             4                    0              0
# 49               15.0             8                    0              0
# 52               17.0             3                    0              0
# 53               15.0             4                    1              0
# 56               13.0             2                    0              0
# 59               29.0             4                    0              0
# 60                NaN             2                    0              0
# 62               21.0             3                    0              0
# 74                NaN             1                    0              0
# 77                NaN             2                    0              0
# 82               22.0             2                    0              0
# 88               17.0             2                    0              0
# 89               14.0             3                    3              0
# 108              18.0             1                    0              0
# 115              13.0             3                    0              0
# 122              13.0             3                    0              0
# 124              17.0             2                    0              0
# 127               NaN             3                    0              0
# 129              23.0             6                    0              0
# 131              10.0             1                    0              0
# 133              23.0             2                    0              0
# 137              13.0             1                    0              0
#
#      url_num_query_para  ...  html_num_tags('iframe')  \
# 2                     0  ...                        0
# 4                     0  ...                        0
# 19                    0  ...                        0
# 21                    0  ...                        1
# 26                    0  ...                        0
# 32                    0  ...                        0
# 33                    0  ...                        0
# 42                    0  ...                        0
# 46                    0  ...                        0
# 49                    0  ...                        1
# 52                    0  ...                        0
# 53                    0  ...                        0
# 56                    0  ...                        0
# 59                    0  ...                        0
# 60                    0  ...                        0
# 62                    0  ...                        0
# 74                    0  ...                        0
# 77                    0  ...                        0
# 82                    0  ...                        0
# 88                    0  ...                        0
# 89                    0  ...                        0
# 108                   0  ...                        0
# 115                   0  ...                        2
# 122                   0  ...                        2
# 124                   0  ...                        0
# 127                   0  ...                        0
# 129                   0  ...                        0
# 131                   0  ...                        0
# 133                   0  ...                        1
# 137                   0  ...                        0
#
#      html_num_tags('script')  html_num_tags('embed')  html_num_tags('object')  \
# 2                        6.0                       3                        3
# 4                        NaN                       0                        0
# 19                       0.0                       0                        0
# 21                       5.0                       0                        0
# 26                      12.0                       0                        0
# 32                       0.0                       0                        0
# 33                       2.0                       0                        0
# 42                       2.0                       0                        0
# 46                       NaN                       0                        0
# 49                      32.0                       0                        0
# 52                       5.0                       0                        0
# 53                       0.0                       0                        0
# 56                       0.0                       0                        0
# 59                       2.0                       0                        0
# 60                       0.0                       0                        0
# 62                       0.0                       0                        0
# 74                      24.0                       0                        0
# 77                       NaN                       1                        1
# 82                       2.0                       0                        0
# 88                       NaN                       0                        0
# 89                       NaN                       0                        0
# 108                     22.0                       0                        0
# 115                      NaN                       0                        0
# 122                      NaN                       0                        0
# 124                     11.0                       0                        0
# 127                      2.0                       0                        0
# 129                      5.0                       0                        0
# 131                     17.0                       0                        0
# 133                      8.0                       1                        1
# 137                      7.0                       0                        0
#
#      html_num_tags('div')  html_num_tags('head')  html_num_tags('body')  \
# 2                      34                      1                      1
# 4                      41                      1                      1
# 19                      0                      1                      1
# 21                     28                      1                      1
# 26                     37                      1                      1
# 32                      1                      1                      1
# 33                     41                      1                      1
# 42                      0                      1                      1
# 46                      3                      1                      1
# 49                     56                      1                      1
# 52                     12                      1                      1
# 53                      3                      1                      1
# 56                      3                      1                      1
# 59                     36                      1                      1
# 60                      4                      1                      1
# 62                      4                      1                      1
# 74                    222                      1                      1
# 77                     60                      1                      1
# 82                     70                      1                      1
# 88                     39                      1                      1
# 89                      0                      1                      1
# 108                   112                      1                      1
# 115                    85                      1                      1
# 122                    16                      1                      1
# 124                    40                      1                      1
# 127                    27                      1                      1
# 129                    18                      1                      1
# 131                   175                      1                      1
# 133                    41                      1                      1
# 137                     6                      1                      1
#
#      html_num_tags('form')  html_num_tags('a')  html_num_tags('applet')
# 2                      0.0               136.0                        0
# 4                      NaN                 NaN                        0
# 19                     NaN                 NaN                        0
# 21                     0.0                31.0                        0
# 26                     0.0                79.0                        0
# 32                     0.0                 NaN                        0
# 33                     NaN                18.0                        0
# 42                     NaN                 2.0                        0
# 46                     0.0                 1.0                        0
# 49                     1.0                 7.0                        0
# 52                     1.0                 3.0                        0
# 53                     NaN                 NaN                        0
# 56                     0.0                 NaN                        0
# 59                     1.0                15.0                        0
# 60                     1.0                 NaN                        0
# 62                     0.0                 0.0                        0
# 74                     4.0               137.0                        0
# 77                     0.0               145.0                        0
# 82                     1.0                13.0                        0
# 88                     3.0                62.0                        0
# 89                     0.0                 NaN                        0
# 108                    1.0                28.0                        0
# 115                    1.0                 NaN                        0
# 122                    1.0                35.0                        0
# 124                    2.0              5874.0                        0
# 127                    1.0                 NaN                        0
# 129                    1.0                 3.0                        0
# 131                    2.0                89.0                        0
# 133                    1.0                72.0                        0
# 137                    0.0                 0.0                        0
#
# [30 rows x 24 columns]

# %% [markdown]
# - 보간법(interpolate)을 사용해서 결측치를 조치해보자.

# %%
#data2 = data.interpolate(method='spline', order=2)

# %%
#data3 = data.interpolate(method='polynomial', order=2)

# %%
data2 = data.interpolate(method='linear')

# %%
data3 = data.fillna(data.median())

# %%
model = joblib.load('./XGB_model.pkl')

# %%
model2 = joblib.load('./XGB_model2.pkl')

# %%
col = ['Unnamed: 0',
    'url_len',
 'url_query_len',
 'url_num_query_para',
'url_chinese_present',
       'url_port',
       "html_num_tags('applet')",
 'url_entropy',
 "html_num_tags('iframe')",
 "html_num_tags('head')",
 "html_num_tags('body')"]

col2 = ['Unnamed: 0', 'url_chinese_present',  "html_num_tags('applet')"]

# %%
test_data1 = data4.drop(col2, axis=1) # (2441, 21)

# %%
test_data1_1 = data2.drop(col2, axis=1)

# %%
test_data2 = data2.drop(col, axis=1)

# %%
test_data3 = data4.drop(col, axis=1)

# %%
test_data.shape
# Out:
# (2441, 13)

# %%
test_data1.shape
# Out:
# (2441, 21)

# %%
test_data.head()
# Out:
#    url_num_hyphens_dom  url_path_len  url_domain_len  url_hostname_len  \
# 0                    0          80.0            17.0              17.0
# 1                    0          22.0            15.0              15.0
# 2                    0          18.0            20.0              20.0
# 3                    0          14.0            26.0              26.0
# 4                    2           7.5            26.0              26.0
#
#    url_num_dots  url_num_underscores  url_ip_present  html_num_tags('script')  \
# 0             4                    0               0                     5.00
# 1             3                    1               0                     5.50
# 2             3                    3               0                     6.00
# 3             2                    0               0                     4.75
# 4             2                    0               0                     3.50
#
#    html_num_tags('embed')  html_num_tags('object')  html_num_tags('div')  \
# 0                       0                        0                    12
# 1                       0                        0                   158
# 2                       3                        3                    34
# 3                       0                        0                    29
# 4                       0                        0                    41
#
#    html_num_tags('form')  html_num_tags('a')
# 0                    1.0                 3.0
# 1                    0.5                69.5
# 2                    0.0               136.0
# 3                    1.0                 2.0
# 4                    1.0                10.0

# %%
pred = model.predict(test_data)

# %%
pred_df = pd.DataFrame(pred)

# %%
pred_df.replace({0:-1}, inplace=True)

# %%
pred_df.index
# Out:
# RangeIndex(start=0, stop=2441, step=1)

# %%
result = pd.DataFrame({'id' : range(2441), 'expected': list(pred)})

# %%
pred1_1 = model.predict(test_data1)
pred1_1 = pd.DataFrame(pred1_1).replace({0:-1}, inplace=True)
result = pd.DataFrame({'id' : range(2441), 'expected': list(pred)})
result.to_csv('result_v1_1.csv', index=False)

# %%
def make_result(model, data, name):
    pred = model.predict(data)
    pred = pd.DataFrame(pred).replace({0:-1}, inplace=True)
    result = pd.DataFrame({'id' : range(2441), 'expected': list(pred)})
    result.to_csv(name, index=False)

# %%
result.isna().sum()
# Out:
# id          0
# expected    0
# dtype: int64

# %%
result.head()
# Out:
#    id  expected
# 0   0        -1
# 1   1         1
# 2   2         1
# 3   3        -1
# 4   4        -1

# %%
result.tail
# Out:
# <bound method NDFrame.tail of         id  expected
# 0        0        -1
# 1        1         1
# 2        2         1
# 3        3        -1
# 4        4        -1
# ...    ...       ...
# 2436  2436         1
# 2437  2437        -1
# 2438  2438        -1
# 2439  2439        -1
# 2440  2440        -1
#
# [2441 rows x 2 columns]>

# %%
result.to_csv('result_v1.csv')

# %%
r_result = pd.read_csv('result_v1.csv')

# %%
r_result.head()
# Out:
#    id  expected
# 0   0        -1
# 1   1         1
# 2   2         1
# 3   3        -1
# 4   4        -1

# %%
pred2 = model2.predict(test_data1)

# %%
make_result(model2, test_data2, 'result_v2_1.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 make_result(model2, test_data2, 'result_v2_1.csv')
#
# Input In [107], in make_result(model, data, name)
#       1 def make_result(model, data, name):
# ----> 2     pred = model.predict(data)
#       3     pred = pd.DataFrame(pred).replace({0:-1}, inplace=True)
#       4     result = pd.DataFrame({'id' : range(2441), 'expected': list(pred)})
#
# File D:\Anaconda\lib\site-packages\xgboost\sklearn.py:1434, in XGBClassifier.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1425 def predict(
#    1426     self,
#    1427     X: ArrayLike,
#    (...)
#    1432     iteration_range: Optional[Tuple[int, int]] = None,
#    1433 ) -> np.ndarray:
# -> 1434     class_probs = super().predict(
#    1435         X=X,
#    1436         output_margin=output_margin,
#    1437         ntree_limit=ntree_limit,
#    1438         validate_features=validate_features,
#    1439         base_margin=base_margin,
#    1440         iteration_range=iteration_range,
#    1441     )
#    1442     if output_margin:
#    1443         # If output_margin is active, simply return the scores
#    1444         return class_probs
#
# File D:\Anaconda\lib\site-packages\xgboost\sklearn.py:1049, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1047 if self._can_use_inplace_predict():
#    1048     try:
# -> 1049         predts = self.get_booster().inplace_predict(
#    1050             data=X,
#    1051             iteration_range=iteration_range,
#    1052             predict_type="margin" if output_margin else "value",
#    1053             missing=self.missing,
#    1054             base_margin=base_margin,
#    1055             validate_features=validate_features,
#    1056         )
#    1057         if _is_cupy_array(predts):
#    1058             import cupy     # pylint: disable=import-error
#
# File D:\Anaconda\lib\site-packages\xgboost\core.py:2128, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2124         raise TypeError(
#    2125             "`shape` attribute is required when `validate_features` is True."
#    2126         )
#    2127     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2128         raise ValueError(
#    2129             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2130             f"got {data.shape[1]}"
#    2131         )
#    2133 from .data import (
#    2134     _is_pandas_df,
#    2135     _transform_pandas_df,
#    (...)
#    2138     _array_interface,
#    2139 )
#    2140 enable_categorical = _has_categorical(self, data)
#
# ValueError: Feature shape mismatch, expected: 21, got 13

# %%
pred2
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
pred_df2 = pd.DataFrame(pred2).replace({0:-1}, inplace=True)
pred2
# Out:
# array([-1, -1,  1, ...,  1, -1,  1])

# %%
result2 = pd.DataFrame({'id' : range(2441), 'expected': list(pred2)})
result2.to_csv('result_v2.csv')

# %%
model3 = joblib.load('./RF_model.pkl')
col3 = ['url_hostname_len','url_path_len','url_query_len',"html_num_tags('a')","html_num_tags('body')","html_num_tags('form')",'url_num_underscores']
test_data2 = data.loc[:, col3]

# %%
pred3 = model3.predict(test_data2)
pred_df3 = pd.DataFrame(pred3).replace({0:-1}, inplace=True)
pred3
# Out:
# array([-1,  1,  1, ...,  1, -1, -1], dtype=int64)

# %%
result3 = pd.DataFrame({'id' : range(2441), 'expected': list(pred3)})
result3.to_csv('result_v3.csv', index=False)

# %%
test_data2.head()
# Out:
#    url_hostname_len  url_path_len  url_query_len  html_num_tags('a')  \
# 0              17.0          80.0              0                 3.0
# 1              15.0          22.0              0                69.5
# 2              20.0          18.0              0               136.0
# 3              26.0          14.0              0                 2.0
# 4              26.0           7.5              0                10.0
#
#    html_num_tags('body')  html_num_tags('form')  url_num_underscores
# 0                      1                    1.0                    0
# 1                      1                    0.5                    1
# 2                      1                    0.0                    3
# 3                      1                    1.0                    0
# 4                      1                    1.0                    0

# %%
model4 = joblib.load('./XGB_model3.pkl')
pred4 = model4.predict(test_data2)
pred4 = pd.DataFrame(pred4).replace({0:-1}, inplace=True)
result4 = pd.DataFrame({'id' : range(2441), 'expected': list(pred4)})
result4.to_csv('result_v4.csv', index=False)
